# %%
import pandas as pd
import numpy as np
df=pd.read_csv("DS_DATESET.csv")
df
# Out:
#        First Name       Last Name        City        State  Zip Code  \
# 0          Barron          Harnes    Kolhapur  Maharashtra    416004
# 1           Velma          Allone        Pune  Maharashtra    411011
# 2         Thibaut        Scotland      Mumbai  Maharashtra    400059
# 3           Retha           Proud     Solapur  Maharashtra    413224
# 4             Del          Pearse      Sangli  Maharashtra    416436
# 5          Farlay          Anstis      Sangli  Maharashtra    416415
# 6           Vanna        Keighley     Solapur  Maharashtra    413224
# 7           Vikki        Ottawell    Kolhapur  Maharashtra    416004
# 8        Stanwood          Ferron      Mumbai  Maharashtra    400055
# 9          Tommie         Rastall    Kolhapur  Maharashtra    416119
# 10    Jacquenetta        Niccolls  NaviMumbai  Maharashtra    400208
# 11          Caleb  Erskine Sandys  NaviMumbai  Maharashtra    400701
# 12       Adelaide      Trebilcock      Sangli  Maharashtra    416436
# ...

# %% [markdown]
# # COLUMNS OF DATASET

# %%
df.columns
# Out:
# Index(['First Name', 'Last Name', 'City', 'State', 'Zip Code',
#        'DOB [DD/MM/YYYY]', 'Age', 'Gender', 'Email Address', 'Contact Number',
#        'Emergency Contact Number', 'College name', 'University Name', 'Degree',
#        'Major/Area of Study', 'Course Type', 'Which-year are you studying in?',
#        'CGPA/ percentage', 'Expected Graduation-year', 'Areas of interest',
#        'Current Employment Status', 'Have you worked core Java',
#        'Programming Language Known other than Java (one major)',
#        'Have you worked on MySQL or Oracle database',
#        'Have you studied OOP Concepts',
#        'Certifications/Achievement/ Research papers',
#        'Rate your written communication skills [1-10]',
#        'Rate your verbal communication skills [1-10]',
#        'Link to updated Resume (Google/ One Drive link preferred)',
#        'link to Linkedin profile', 'How Did You Hear About This Internship?',
#        'Label'],
#       dtype='object')

# %% [markdown]
# # CLEANING AND ENCODING DATA

# %%
df=df.drop(["Email Address"],axis=1)
df=df.drop(["First Name"],axis=1)
df=df.drop(["Last Name"],axis=1)
df=df.drop(["Zip Code"],axis=1)
df=df.drop(["Contact Number"],axis=1)
df=df.drop(["Emergency Contact Number"],axis=1)
df=df.drop(["University Name"],axis=1)
df=df.drop(["Degree"],axis=1)
df=df.drop(["Course Type"],axis=1)
df=df.drop(["Current Employment Status"],axis=1)
df=df.drop(["Expected Graduation-year"],axis=1)
df=df.drop(["State"],axis=1)
df=df.drop(["Certifications/Achievement/ Research papers"],axis=1)
df=df.drop(["DOB [DD/MM/YYYY]"],axis=1)
df=df.drop(["Link to updated Resume (Google/ One Drive link preferred)"],axis=1)
df=df.drop(["link to Linkedin profile"],axis=1)

# %%
lbl=df["Label"].tolist()
x=[]
for i in range(0,len(lbl)):
    if lbl[i]=='eligible':
        x.append(1)
    else:
        x.append(0)

# %%
Label=pd.DataFrame({"Label":x})

# %%
df=df.drop(["Label"],axis=1)

# %%
df=pd.concat([df,Label],axis=1,sort=False)

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # 1)NO OF STUDENTS AND THEIR TECHNOLOGY

# %%
dftech=df["Areas of interest"]

dftechplot=dftech.value_counts().to_frame()
dftechplot
# Out:
#                           Areas of interest
# DevOps                                  674
# Machine Learning                        671
# Python                                  652
# Cyber Security                          638
# Web Development                         637
# QMS/Testing                             633
# Mobility                                631
# IoT                                     630
# Artificial Intelligence                 627
# Digital Marketing                       624
# Blockchain                              623
# Big Data                                612
# Data Science                            601
# Information Security                    598
# RPA                                     589
# Cloud Computing                         560

# %%
dftechplot.plot(kind='bar', figsize=(15, 6),color="orange")




plt.xlabel('Areas of Interest')
plt.ylabel('Number of Applicants')
plt.title('Technology and Its Applicants')
plt.show()

# %% [markdown]
# # 2) The number of students who applied for Data Science and who knew ‘’Python” and who did not

# %% [markdown]
# ### choosing the required columns

# %%
df1=df[["Areas of interest","Programming Language Known other than Java (one major)"]]

# %%
area=df1.groupby(["Areas of interest"])#grouping via technology

# %%
area1 = area.get_group('Data Science ')#getting data science applicants choices
interestplot=area1["Programming Language Known other than Java (one major)"].value_counts().to_frame()
interestplot
# Out:
#             Programming Language Known other than Java (one major)
# HTML/CSS                                                   86
# JavaScript                                                 82
# C++                                                        80
# C#                                                         75
# C                                                          74
# .Net                                                       74
# Python                                                     66
# PHP                                                        64

# %%
interestplot.plot(kind='bar', figsize=(15, 6),color="red")


plt.xlabel('Programming Language Known other than Java (one major)')
plt.ylabel('Number of Applicants')
plt.title('Major Language known by Data Science Applicants')
plt.show()

# %% [markdown]
# # 66 people know python who applied for Data Science

# %% [markdown]
# # 3)How did you hear about internship

# %%
dfhow=df["How Did You Hear About This Internship?"]
dfhowplot=dfhow.value_counts().to_frame()
dfhowplot
# Out:
#                      How Did You Hear About This Internship?
# Intern                                                  1173
# Newspaper                                               1162
# Twitter                                                 1160
# Blog post                                               1116
# LinkedIn                                                1112
# Friend                                                  1109
# Facebook                                                1084
# Other                                                   1077
# Ex/Current Employee                                     1007

# %%
dfhowplot.plot(kind='bar', figsize=(15, 6),color="green")


plt.xlabel("How Did You Hear About This Internship?")
plt.ylabel('Number of Applicants')
plt.title('News of internship from different mediums')
plt.show()

# %% [markdown]
# # 4) Students who are in the fourth year and have a CGPA greater than 8.0.

# %%
df2=df[["Which-year are you studying in?","CGPA/ percentage"]]

# %%
cgpa=df2.groupby(["Which-year are you studying in?"])

# %%
fourthyear=cgpa.get_group('Fourth-year')
fourthyear1=fourthyear.reset_index(drop=True)

# %%
x=[]
x=fourthyear1["CGPA/ percentage"]
greaterthan=[]
for i in range(0,len(fourthyear1)):
    if x[i] >8.0:
        greaterthan.append("YES")
    elif x[i]<8.0 :
        greaterthan.append("NO")

# %%
finalcount=pd.DataFrame({"Greater Than 8.0":greaterthan})
cgpaplot=finalcount["Greater Than 8.0"].value_counts().to_frame()
cgpaplot
# Out:
#      Greater Than 8.0
# YES              1697
# NO                773

# %%
cgpaplot.plot(kind='bar', figsize=(8, 6),color="purple")


plt.xlabel("CGPA")
plt.ylabel('Number of Applicants in Fourth Year')
plt.title('CGPA of Fourth Year Students')
plt.show()

# %% [markdown]
# # 1697 Fourth Year Students have cgpa greater than 8.0

# %%
#alternate way to show this questions answer in one step
len(df[(df['Which-year are you studying in?']=="Fourth-year") & (df['CGPA/ percentage']>8.0)])
# Out:
# 1697

# %% [markdown]
# # 5) Students who applied for Digital Marketing with verbal and written communication score greater than 8.

# %%
dfdigital=df[["Areas of interest","Rate your verbal communication skills [1-10]","Rate your written communication skills [1-10]"]]

# %%
grpdigital=dfdigital.groupby(["Areas of interest"])

# %%
digi=grpdigital.get_group("Digital Marketing ")

# %%
digi1=digi.reset_index(drop=True)

# %%
y=digi1["Rate your verbal communication skills [1-10]"].tolist()
z=digi1["Rate your written communication skills [1-10]"].tolist()

# %%
grt=[]
for i in range(0,624):
    if y[i]  > 8:
        if z[i]>8:
            grt.append("YES")
        elif z[i]==8:
            grt.append("NO")
        else :
            grt.append("NO")
    elif y[i]==8:
        grt.append("NO")
        
    else:
        grt.append("NO")

# %%
finalcount1=pd.DataFrame({"Greater Than 8":grt})
communicationplot=finalcount1["Greater Than 8"].value_counts().to_frame()
communicationplot
# Out:
#      Greater Than 8
# NO              532
# YES              92

# %%
communicationplot.plot(kind='bar', figsize=(8, 6),color="grey")


plt.xlabel("Verbal Rating")
plt.ylabel('Number of Applicants in Digital Marketing')
plt.title('Verbal and Written Communication Skills of Digital Marketing Applicants')
plt.show()

# %% [markdown]
# # 92 Digital Marketing Applicants had rated themselves above 8 in verbal and written communication skills.

# %% [markdown]
# # 6a) YEAR WISE CLASSIFICATION

# %%
dfyear=df["Which-year are you studying in?"]

# %%
dfyearplot=dfyear.value_counts().to_frame()
dfyearplot
# Out:
#              Which-year are you studying in?
# Second-year                             2550
# First-year                              2510
# Fourth-year                             2477
# Third-year                              2463

# %%
dfyearplot.plot(kind='bar', figsize=(12, 6),color="black")


plt.xlabel("Year")
plt.ylabel('Number of Applicants')
plt.title('YEAR WISE CLASSIFICATION')
plt.show()

# %% [markdown]
# # 6b) AREA OF STUDY CLASSIFICATION

# %%
dfstudy=df["Major/Area of Study"]

# %%
dfstudyplot=dfstudy.value_counts().to_frame()
dfstudyplot
# Out:
#                                    Major/Area of Study
# Computer Engineering                              5971
# Electrical Engineering                            2033
# Electronics and Telecommunication                 1996

# %%
dfstudyplot.plot(kind='barh', figsize=(8, 6),color="cyan")
plt.ylabel("Major/Area of Study")
plt.xlabel('Number of Applicants')
plt.title('AREA OF STUDY  CLASSIFICATION')
plt.show()

# %% [markdown]
# # 7a) CITY WISE CLASSIFICATION

# %%
dfstay=df["City"]

# %%
dfstayplot=dfstay.value_counts().to_frame()
dfstayplot
# Out:
#             City
# Solapur     1710
# NaviMumbai  1678
# Sangli      1670
# Mumbai      1648
# Kolhapur    1647
# Pune        1647

# %%
dfstayplot.plot(kind='bar', figsize=(15, 6),color="pink")
plt.xlabel("City")
plt.ylabel('Number of Applicants')
plt.title('CITY BASED CLASSIFICATION')
plt.show()

# %% [markdown]
# # 7b) COLLEGE WISE CLASSIFICATION

# %%
dfcollege=df["College name"]

# %%
dfcollegeplot=dfcollege.value_counts().to_frame()
dfcollegeplot
# Out:
#                                                     College name
# Rajarambapu Institute of Technology                         1670
# Bharati Vidyapeeth College of Engineering                    834
# DY Patil College of Engineering And Technology               813
# Walchand Institute of Technology                             434
# Skn Sinhgad College of Engineering                           431
# Brahmdevdada Mane Institute of Technology                    428
# Bharat Ratna Indira Gandhi College of Engineering            417
# Karamveer Bhauro Patil College                               378
# Pillai College of Engineering                                356
# Sinhgad College of Engineering                               340
# D. Y. Patil College of Engineering                           338
# Mahatma Gandhi Mission's College of Engineering...           329
# Pune Institute of Computer Technology                        329
# ...

# %%
dfcollegeplot.plot(kind='barh', figsize=(15, 8),color="blue")
plt.ylabel("College Name")
plt.xlabel('Number of Applicants')
plt.title('COLLEGE WISE CLASSIFICATION')
plt.show()

# %% [markdown]
# # 8) Plot the relationship between CGPA and Target Variable

# %%
import seaborn as sns

# %%
sns.regplot(x="CGPA/ percentage",y="Label",data=df)

# %%
df[["CGPA/ percentage", "Label"]].corr()
# Out:
#                   CGPA/ percentage     Label
# CGPA/ percentage          1.000000  0.228111
# Label                     0.228111  1.000000

# %% [markdown]
# # CGPA and target variable have a weak positive correlation of 0.228111

# %% [markdown]
# # 9) Plot the relationship between Area of interest and Target Variable

# %%
dfencode=df

# %%
dfencode["Areas of interest"] = dfencode["Areas of interest"].astype('category')

# %%
dfencode["Areas of interest"] = dfencode["Areas of interest"].cat.codes

# %%
sns.regplot(x="Areas of interest",y="Label",data=dfencode)

# %%
dfencode[["Areas of interest", "Label"]].corr()
# Out:
#                    Areas of interest     Label
# Areas of interest           1.000000 -0.010052
# Label                      -0.010052  1.000000

# %% [markdown]
# # Areas of interest and Target Variable have a very weak negative relationship of -0.010052.

# %% [markdown]
# # 10) Plot the relationship between Year of study ,Major and Target Variable

# %%
dfencode["Which-year are you studying in?"]=dfencode["Which-year are you studying in?"].astype("category")

# %%
dfencode["Which-year are you studying in?"]=dfencode["Which-year are you studying in?"].cat.codes

# %%
dfencode["Major/Area of Study"]=dfencode["Major/Area of Study"].astype("category")

# %%
dfencode["Major/Area of Study"]=dfencode["Major/Area of Study"].cat.codes

# %%
dfencode
# Out:
#             City  Age  Gender  \
# 0       Kolhapur   19    Male
# 1           Pune   22  Female
# 2         Mumbai   24    Male
# 3        Solapur   20  Female
# 4         Sangli   23  Female
# 5         Sangli   20    Male
# 6        Solapur   20  Female
# 7       Kolhapur   21  Female
# 8         Mumbai   20    Male
# 9       Kolhapur   22    Male
# 10    NaviMumbai   21  Female
# 11    NaviMumbai   21    Male
# 12        Sangli   21  Female
# 13       Solapur   23    Male
# 14    NaviMumbai   24  Female
# 15       Solapur   21  Female
# 16    NaviMumbai   19    Male
# 17        Sangli   21    Male
# 18       Solapur   19  Female
# 19      Kolhapur   24  Female
# 20        Sangli   23  Female
# 21        Sangli   20    Male
# 22          Pune   19    Male
# 23       Solapur   22    Male
# 24        Sangli   23    Male
# 25        Sangli   21    Male
# 26        Sangli   21  Female
# 27    NaviMumbai   23  Female
# 28        Mumbai   22  Female
# 29        Mumbai   22  Female
# ...

# %%
sns.regplot(x="Major/Area of Study",y="Label",data=dfencode)

# %%
dfencode[["Major/Area of Study", "Label"]].corr()
# Out:
#                      Major/Area of Study     Label
# Major/Area of Study             1.000000 -0.006358
# Label                          -0.006358  1.000000

# %%
sns.regplot(x="Which-year are you studying in?",y="Label",data=dfencode)

# %%
dfencode[["Which-year are you studying in?", "Label"]].corr()
# Out:
#                                  Which-year are you studying in?     Label
# Which-year are you studying in?                         1.000000  0.373285
# Label                                                   0.373285  1.000000

# %% [markdown]
# # MACHINE LEARNING MODELS

# %%
df.columns
# Out:
# Index(['City', 'Age', 'Gender', 'College name', 'Major/Area of Study',
#        'Which-year are you studying in?', 'CGPA/ percentage',
#        'Areas of interest', 'Have you worked core Java',
#        'Programming Language Known other than Java (one major)',
#        'Have you worked on MySQL or Oracle database',
#        'Have you studied OOP Concepts',
#        'Rate your written communication skills [1-10]',
#        'Rate your verbal communication skills [1-10]',
#        'How Did You Hear About This Internship?', 'Label'],
#       dtype='object')

# %%
# encoding remaining categorical variables

# %%
dfencode["City"]=dfencode["City"].astype("category")
dfencode["City"]=dfencode["City"].cat.codes

# %%
dfencode["Gender"]=dfencode["Gender"].astype("category")
dfencode["Gender"]=dfencode["Gender"].cat.codes

# %%
dfencode["College name"]=dfencode["College name"].astype("category")
dfencode["College name"]=dfencode["College name"].cat.codes

# %%
dfencode["Have you worked core Java"]=dfencode["Have you worked core Java"].astype("category")
dfencode["Have you worked core Java"]=dfencode["Have you worked core Java"].cat.codes

# %%
dfencode["Programming Language Known other than Java (one major)"]=dfencode["Programming Language Known other than Java (one major)"].astype("category")
dfencode["Programming Language Known other than Java (one major)"]=dfencode["Programming Language Known other than Java (one major)"].cat.codes

# %%
dfencode["Have you worked on MySQL or Oracle database"]=dfencode["Have you worked on MySQL or Oracle database"].astype("category")
dfencode["Have you worked on MySQL or Oracle database"]=dfencode["Have you worked on MySQL or Oracle database"].cat.codes

# %%
dfencode["Have you studied OOP Concepts"]=dfencode["Have you studied OOP Concepts"].astype("category")
dfencode["Have you studied OOP Concepts"]=dfencode["Have you studied OOP Concepts"].cat.codes

# %%
dfencode["Rate your written communication skills [1-10]"]=dfencode["Rate your written communication skills [1-10]"].astype("category")
dfencode["Rate your written communication skills [1-10]"]=dfencode["Rate your written communication skills [1-10]"].cat.codes

# %%
dfencode["Rate your verbal communication skills [1-10]"]=dfencode["Rate your verbal communication skills [1-10]"].astype("category")
dfencode["Rate your verbal communication skills [1-10]"]=dfencode["Rate your verbal communication skills [1-10]"].cat.codes

# %%
dfencode["How Did You Hear About This Internship?"]=dfencode["How Did You Hear About This Internship?"].astype("category")
dfencode["How Did You Hear About This Internship?"]=dfencode["How Did You Hear About This Internship?"].cat.codes

# %%
from sklearn import preprocessing

# %%
X = np.asarray(dfencode[['City', 'Age', 'Gender', 'College name', 'Major/Area of Study', 'Which-year are you studying in?', 'CGPA/ percentage','Areas of interest','Have you worked core Java','Programming Language Known other than Java (one major)','Have you worked on MySQL or Oracle database','Have you studied OOP Concepts','Rate your written communication skills [1-10]','Rate your verbal communication skills [1-10]','How Did You Hear About This Internship?']])

# %%
y = np.asarray(dfencode['Label'])

# %%
X = preprocessing.StandardScaler().fit(X).transform(X)

# %%
# splitting data in train and test

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
LR = LogisticRegression(C=0.01, solver='liblinear').fit(X_train,y_train)
LR
# Out:
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
yhat = LR.predict(X_test)

# %%
yhat_prob = LR.predict_proba(X_test)

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.777

# %%
from sklearn.metrics import f1_score
f1_score(y_test,yhat)
# Out:
# 0.7194968553459119

# %%
from sklearn.metrics import log_loss
log_loss(y_test, yhat_prob)
# Out:
# 0.4497756537522598

# %% [markdown]
# # With logistic regression we get 77.7%  accuracy and f1score of 71%

# %% [markdown]
# # STOCHASTIC GRADIENT DESCENT

# %%
from sklearn.linear_model import SGDClassifier
clf3 = SGDClassifier(loss="hinge", penalty="l2", max_iter=100)
clf3.fit(X, y)
SGDClassifier
# Out:
# sklearn.linear_model.stochastic_gradient.SGDClassifier

# %%
yhat5 = clf3.predict(X_test)
jaccard_similarity_score(y_test, yhat5)
# Out:
# 0.7715

# %%
from sklearn.metrics import f1_score
f1_score(y_test,yhat5)
# Out:
# 0.7198038013488657

# %% [markdown]
# # with sgd we get 78% accuracy and f1score of 72%

# %% [markdown]
# # K NEAREST NEIGHBOURS

# %%
from sklearn.neighbors import KNeighborsClassifier

k = 100
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
yhat1 = neigh.predict(X_test)
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat1))
# Out:
# Train set Accuracy:  0.852
# Test set Accuracy:  0.8425

# %%
from sklearn.metrics import f1_score
f1_score(y_test,yhat1)
# Out:
# 0.8105832832230907

# %% [markdown]
# # with k nearest neighbours we get 84% accuracy and f1score of 81%.

# %% [markdown]
# # NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred = gnb.predict(X_test)
jaccard_similarity_score(y_test, y_pred)
# Out:
# 0.8695

# %%
from sklearn.metrics import f1_score
f1_score(y_test,y_pred)
# Out:
# 0.8215994531784004

# %% [markdown]
# # with naive bayes we get 86.95 % accuracy and f1score of 82%.

# %% [markdown]
# # SVM

# %%
from sklearn import svm
clf1 = svm.SVC(kernel='rbf')
clf1.fit(X_train, y_train) 
yhat2 = clf1.predict(X_test)
jaccard_similarity_score(y_test, yhat2)
# Out:
# 0.954

# %%
# after hyperparameter tuning

# %%
clf2 = svm.SVC(kernel='rbf',C=100,gamma=0.1)
clf2.fit(X_train, y_train) 
yhat3 = clf2.predict(X_test)
jaccard_similarity_score(y_test, yhat3)
# Out:
# 0.971

# %%
from sklearn.metrics import f1_score
f1_score(y_test,yhat3)
# Out:
# 0.9642416769420469

# %% [markdown]
# # with SVM   accuracy is  97.1% and f1score of 96.4%.

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier=RandomForestClassifier() 
classifier=classifier.fit(X_train,y_train) 
yhat4=classifier.predict(X_test) 
jaccard_similarity_score(y_test, yhat4)
# Out:
# 1.0

# %%
from sklearn.metrics import f1_score
f1_score(y_test,yhat4)
# Out:
# 1.0

# %% [markdown]
# # with random forest classifier got 100% accuracy and 100% f1score.

# %% [markdown]
# # -------------------------DONE ---------------------------
# # THANK YOU FOR THIS AMAZING PROJECT
